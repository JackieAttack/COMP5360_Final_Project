# %% [markdown]
# Group 22
# COMP5360 Final Project
#
# Project title:  Investigating the Impacts of Climate Change on the Marine Economy and U.S. Fisheries
#
#
# Group members:
# Jackie Bearnson u0763123@umail.utah.edu U0763123
# Yueqin Yang yueqin.yang@hsc.utah.edu U0737683
# Siwei Zhou,u1421984@umail.utah.edu,u1421984

# %%
import pandas as pd
import numpy as np

# %%
#The data was downloaded from https://www.kaggle.com/datasets/sohier/calcofi?select=bottle.csv 
#The excel file is 245mb, too large to open
#Read excel file FoodAccessResearchAtlasData2019, to see how many spreadsheet in that file
df = pd.read_csv('C:\\Users\\yueqi\\Downloads\\bottle.csv\\bottle.csv')
df
# Out:
# C:\Users\yueqi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1             1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2             1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3             1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4             1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...         ...      ...          ...                                     ...
# 864858    34404   864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# ...

# %% [markdown]
# Here's a brief description of each feature:
#
# Cst_Cnt: Cast count (unique identifier for each cast, or deployment of sampling equipment)
# Btl_Cnt: Bottle count (unique identifier for each water sample)
# Sta_ID: Station ID (unique identifier for each sampling station)
# Depth_ID: Depth ID (unique identifier for each depth at which a sample was collected)
# Depthm: Depth of sample in meters
# T_degC: Temperature in degrees Celsius
# Salnty: Salinity (amount of salt in seawater)
# O2ml_L: Dissolved oxygen concentration in milliliters per liter
# STheta: Potential density relative to seawater (a measure of water mass density)
# O2Sat: Oxygen saturation (percent of oxygen present in seawater compared to the maximum amount it can hold)
# Oxy_µmol/Kg: Dissolved oxygen concentration in micromoles per kilogram
# BtlNum: Bottle number (same as Btl_Cnt)
# RecInd: Record indicator (indicates if the record is the best value for the parameter measured at that station and depth)
# T_prec: Temperature precision
# T_qual: Temperature quality flag
# S_prec: Salinity precision
# S_qual: Salinity quality flag
# P_qual: Pressure quality flag
# O_qual: Oxygen quality flag
# SThtaq: Potential density quality flag
# O2Satq: Oxygen saturation quality flag
# ChlorA: Chlorophyll A concentration (a measure of phytoplankton biomass)
# Chlqua: Chlorophyll A quality flag
# Phaeop: Phaeophytin concentration (a measure of the breakdown of chlorophyll A)
# Phaqua: Phaeophytin quality flag
# PO4uM: Phosphate concentration in micromoles per liter
# PO4q: Phosphate quality flag
# SiO3uM: Silicate concentration in micromoles per liter
# SiO3qu: Silicate quality flag
# NO2uM: Nitrite concentration in micromoles per liter
# NO2q: Nitrite quality flag
# NO3uM: Nitrate concentration in micromoles per liter
# NO3q: Nitrate quality flag
# NH3uM: Ammonia concentration in micromoles per liter
# NH3q: Ammonia quality flag
# C14As1: Carbon-14 activity in the surface layer
# C14A1p: Carbon-14 activity quality flag for the surface layer
# C14A1q: Carbon-14 activity quality flag for the surface layer
# C14As2: Carbon-14 activity in the deep layer
# C14A2p: Carbon-14 activity quality flag for the deep layer
# C14A2q: Carbon-14 activity quality flag for the deep layer
# DarkAs: Dark bottle carbon-14 activity
# DarkAp: Dark bottle carbon-14 activity quality flag
# DarkAq: Dark bottle carbon-14 activity quality flag
# MeanAs: Mean surface layer carbon-14 activity
# MeanAp: Mean surface layer carbon-14 activity quality flag
# MeanAq: Mean surface layer carbon-14 activity quality flag
# IncTim: Incubation time for primary productivity measurement
# LightP: Light percentage for primary productivity measurement
# R_Depth: Reference depth
# R_TEMP: Reference temperature
# R_POTEMP: Reference potential temperature
# R_SAL

# %%
#The features that we will use are ""
# print the column names
print(data.columns)
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'BtlNum',
#        'RecInd', 'T_prec', 'T_qual', 'S_prec', 'S_qual', 'P_qual', 'O_qual',
#        'SThtaq', 'O2Satq', 'ChlorA', 'Chlqua', 'Phaeop', 'Phaqua', 'PO4uM',
#        'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q', 'NH3uM',
#        'NH3q', 'C14As1', 'C14A1p', 'C14A1q', 'C14As2', 'C14A2p', 'C14A2q',
#        'DarkAs', 'DarkAp', 'DarkAq', 'MeanAs', 'MeanAp', 'MeanAq', 'IncTim',
#        'LightP', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA',
#        'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3',
#        'R_NO2', 'R_NH4', 'R_CHLA', 'R_PHAEO', 'R_PRES', 'R_SAMP', 'DIC1',
#        'DIC2', 'TA1', 'TA2', 'pH2', 'pH1', 'DIC Quality Comment'],
#       dtype='object')

# %%
#'Depth_ID':[Century]-[YY][MM][ShipCode]-[CastType][Julian Day]-[CastTime]-[Line][Sta][Depth][Bottle]-[Rec_Ind]
#Depthm: Depth in meters
#'T_degC':  Water temperature in degree Celsius
#'Salnty':Salinity in g of salt per kg of water (g/kg)
#'O2ml_L': O2 mixing ration in ml/L
#O2Sat: Oxygen saturation (percent of oxygen present in seawater compared to the maximum amount it can hold)
#ChlorA: Chlorophyll A concentration (a measure of phytoplankton biomass)
#P_qual: Pressure quality flag
#O_qual: Oxygen quality flag
#SThtaq: Potential density quality flag
#O2Satq: Oxygen saturation quality flag

# %%
import pandas as pd

# extract year and month information from 'Column1' column and create two new columns 'year' and 'month'
df['year'] = df['Depth_ID'].str[:2] + df['Depth_ID'].str[3:5]
df['month'] = df['Depth_ID'].str[5:7]

df
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1             1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2             1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3             1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4             1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...         ...      ...          ...                                     ...
# 864858    34404   864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# 864860    34404   864861  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3
# 864861    34404   864862  093.4 026.4  20-1611SR-MX-310-2239-09340264-0010A-3
# 864862    34404   864863  093.4 026.4  20-1611SR-MX-310-2239-09340264-0015A-3
#
# ...

# %%
df_depth0 = df[df['Depthm'] == 0]
df_depth0
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 29            2       30  052.0 075.0  19-4903CR-HY-060-2112-05200750-0000B-3
# 61            3       62  051.0 085.0  19-4903CR-HY-061-0354-05100850-0000B-3
# 92            4       93  050.0 095.0  19-4903CR-HY-061-1042-05000950-0000B-3
# 123           5      124  050.0 104.0  19-4903CR-HY-061-1706-05001040-0000B-3
# ...         ...      ...          ...                                     ...
# 864731    34400   864732  093.3 090.0  20-1611SR-MX-313-0314-09330900-0000A-7
# 864762    34401   864763  093.3 100.0  20-1611SR-MX-313-0851-09331000-0000A-7
# 864795    34402   864796  093.3 110.0  20-1611SR-MX-313-1448-09331100-0000A-7
# 864827    34403   864828  093.3 120.0  20-1611SR-MX-313-2053-09331200-0000A-7
# 864858    34404   864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
#
# ...

# %%
# select only the rows with year 1990
df_1990 = df[df['year'] == '1990']

# print the resulting dataframe
print(df_1990)
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 643796    26373   643797  093.3 026.7  19-9003JD-HY-063-2123-09330267-0000B-7
# 643797    26373   643798  093.3 026.7  19-9003JD-HY-063-2123-09330267-0001A-3
# 643798    26373   643799  093.3 026.7  19-9003JD-HY-063-2123-09330267-0010A-7
# 643799    26373   643800  093.3 026.7  19-9003JD-HY-063-2123-09330267-0013A-3
# 643800    26373   643801  093.3 026.7  19-9003JD-HY-063-2123-09330267-0020A-7
# ...         ...      ...          ...                                     ...
# 651496    26664   651497  076.7 049.0  19-9011NM-HY-323-1652-07670490-0031A-3
# 651497    26664   651498  076.7 049.0  19-9011NM-HY-323-1652-07670490-0042A-3
# 651498    26664   651499  076.7 049.0  19-9011NM-HY-323-1652-07670490-0050A-7
# 651499    26664   651500  076.7 049.0  19-9011NM-HY-323-1652-07670490-0052A-3
# 651500    26664   651501  076.7 049.0  19-9011NM-HY-323-1652-07670490-0063A-3
#
# ...

# %%
df_1990_select = df_1990[['month','Depthm', 'T_degC','Salnty','pH2','pH1']]
df_1990_select
# Out:
#        month  Depthm  T_degC  Salnty  pH2  pH1
# 643796    03       0   14.36  33.389  NaN  NaN
# 643797    03       1   14.36  33.389  NaN  NaN
# 643798    03      10   13.87  33.412  NaN  NaN
# 643799    03      13   13.62  33.425  NaN  NaN
# 643800    03      20   13.21  33.452  NaN  NaN
# ...      ...     ...     ...     ...  ...  ...
# 651496    11      31   14.89  33.388  NaN  NaN
# 651497    11      42   14.50  33.381  NaN  NaN
# 651498    11      50   13.39  33.360  NaN  NaN
# 651499    11      52   13.12  33.357  NaN  NaN
# 651500    11      63   12.85  33.361  NaN  NaN
#
# [7705 rows x 6 columns]

# %%
#draw scatter plot of depthm and salnty, tempertaure
# extract data for March only
import pandas as pd
import matplotlib.pyplot as plt

df_march = df_1990_select[df_1990_select['month'] == '03']

# create a scatter plot of temperature vs depth
plt.scatter(df_march['Depthm'], df_march['T_degC'], label='Temperature', color='blue')
plt.scatter(df_march['Depthm'], df_march['Salnty'], label='Salinity', color='red')
plt.xlabel('Depth (m)')
plt.ylabel('Temperature (°C) / Salinity (psu)')
plt.title('Temperature and Salinity vs Depth in March')
plt.legend()
plt.show()

# %%
df_march
# Out:
#        month  Depthm  T_degC  Salnty
# 643796    03       0   14.36  33.389
# 643797    03       1   14.36  33.389
# 643798    03      10   13.87  33.412
# 643799    03      13   13.62  33.425
# 643800    03      20   13.21  33.452
# ...      ...     ...     ...     ...
# 645669    03      30   10.34  33.703
# 645670    03      31   10.33  33.707
# 645671    03      41   10.18  33.767
# 645672    03      50   10.09  33.792
# 645673    03      52   10.07  33.797
#
# [1878 rows x 4 columns]

# %%
plt.hist(df_march['Depthm'])
# Out:
# (array([673., 359., 243., 151., 114.,  92.,  94.,  33.,  93.,  26.]),
#  array([  0. ,  59.2, 118.4, 177.6, 236.8, 296. , 355.2, 414.4, 473.6,
#         532.8, 592. ]),
#  <BarContainer object of 10 artists>)

# %%
df_march.groupby('Depthm').count()
#will use Depthm as 0, for T_degC, Salnty
# Out:
#         month  T_degC  Salnty
# Depthm
# 0          71      71      71
# 1          46      46      46
# 2           2       2       2
# 3           4       4       4
# 5           1       1       1
# ...       ...     ...     ...
# 571         1       1       1
# 585         1       1       1
# 587         1       1       1
# 590         1       1       1
# 592         1       1       1
#
# [326 rows x 3 columns]

# %%
# apply the describe() function to the numeric columns
desc = df_march.describe()
desc
# Out:
#             Depthm       T_degC       Salnty
# count  1878.000000  1877.000000  1872.000000
# mean    151.641108    10.507139    33.751243
# std     148.446507     2.630752     0.344343
# min       0.000000     5.240000    33.076000
# 25%      31.000000     8.460000    33.460000
# 50%     100.000000    10.440000    33.682000
# 75%     230.000000    12.840000    34.079000
# max     592.000000    15.260000    34.356000

# %%
#'Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
 #      'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'BtlNum',
#       'RecInd', 'T_prec', 'T_qual', 'S_prec', 'S_qual', 'P_qual', 'O_qual',
 #      'SThtaq', 'O2Satq', 'ChlorA', 'Chlqua', 'Phaeop', 'Phaqua', 'PO4uM',
 #      'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q', 'NH3uM',
 ##      'NH3q', 'C14As1', 'C14A1p', 'C14A1q', 'C14As2', 'C14A2p', 'C14A2q',
  #     'LightP', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA',
 #      'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3',
  #     'R_NO2', 'R_NH4', 'R_CHLA', 'R_PHAEO', 'R_PRES', 'R_SAMP', 'DIC1',
  #     'DIC2', 'TA1', 'TA2', 'pH2', 'pH1', 'DIC Quality Comment'],

df1 = df['Sta_ID', 'Depth_ID', 'Depthm', 'T_degC']

# %%
# get a list of all unique depth values
depths1 = df['Depth_ID'].unique()
depths1
# Out:
# array(['19-4903CR-HY-060-0930-05400560-0000A-3',
#        '19-4903CR-HY-060-0930-05400560-0008A-3',
#        '19-4903CR-HY-060-0930-05400560-0010A-7', ...,
#        '20-1611SR-MX-310-2239-09340264-0005A-3',
#        '20-1611SR-MX-310-2239-09340264-0010A-3',
#        '20-1611SR-MX-310-2239-09340264-0015A-3'], dtype=object)

# %%
len  
depths2 = df['Depthm'].unique()
depths2
# Out:
# array([   0,    8,   10, ..., 3499, 2001, 3501], dtype=int64)

# %%
len(depths2)
# Out:
# 3219

# %%
len(df)
# Out:
# 864863

# %%
# create a new df with True if the value contains "19-49" and False otherwise
df_1949_03 = df['Depth_ID'].str.contains('19-4903')

# %%
df_1949
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 864858    False
# 864859    False
# 864860    False
# 864861    False
# 864862    False
# Name: Depth_ID, Length: 864863, dtype: bool

# %%
# create a new column 'match' with True if the value contains "19-49" and False otherwise
df['match'] = df['Column1'].str.contains('19-49')

# only keep the rows where the 'match' column is True
df = df[df['match']]

# print the resulting dataframe
print(df)
