# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('merged_depth1_calco_CPI_PPI_Major_species.csv')

# %%
selected_features = df[['Year','Depthm','T_degC', 'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'SThtaq', 'ChlorA', 'Phaeop', 'Phaqua', 'PO4uM', 'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'C14As1', 'C14A1p', 'C14As2', 'C14A2p', 'DarkAs', 'MeanAs', 'MeanAp', 'MeanAq', 'LightP', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA', 'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3', 'R_NO2', 'R_CHLA', 'R_PHAEO', 'R_PRES','CPI','CRUSTACEA','MAMMALIA','MOLLUSCA','PISCES','Abalones nei']]

# %%
selected_features
# Out:
#     Year  Depthm     T_degC     Salnty    O2ml_L     STheta       O2Sat  \
# 0   1950     1.0  19.540000  33.170000  4.955000  23.486500   94.100000
# 1   1951     1.0  14.220000        NaN  5.580000        NaN         NaN
# 2   1952     1.0  19.330000  33.490000       NaN  23.785000         NaN
# 3   1954     1.0  18.525000  33.535000  5.277500  24.122750  104.250000
# 4   1955     1.0  17.746608  33.760167  5.393407  24.316847  101.744078
# ..   ...     ...        ...        ...       ...        ...         ...
# 84  2019     NaN        NaN        NaN       NaN        NaN         NaN
# 85  2020     NaN        NaN        NaN       NaN        NaN         NaN
# 86  2021     NaN        NaN        NaN       NaN        NaN         NaN
# 87  2022     NaN        NaN        NaN       NaN        NaN         NaN
# 88  2023     NaN        NaN        NaN       NaN        NaN         NaN
#
#     Oxy_µmol/Kg    SThtaq  ChlorA  ...   R_DYNHT      R_O2  R_O2Sat  R_SIO3  \
# ...

# %%
df_selected_features = selected_features.dropna(subset=['T_degC', 'Salnty','O2ml_L','O2Sat', 'Oxy_µmol/Kg','CPI','CRUSTACEA','MAMMALIA','MOLLUSCA','PISCES','Abalones nei'])

#

# %%
df_selected_features_dropna = df_selected_features[['T_degC', 'Salnty','O2ml_L','O2Sat', 'Oxy_µmol/Kg','CPI','CRUSTACEA','MAMMALIA','MOLLUSCA','PISCES','Abalones nei']]

# %%
df_selected_features_dropna
# Out:
#        T_degC     Salnty    O2ml_L       O2Sat  Oxy_µmol/Kg         CPI  \
# 0   19.540000  33.170000  4.955000   94.100000   216.212200   19.366667
# 3   18.525000  33.535000  5.277500  104.250000   245.060850   20.841667
# 4   17.746608  33.760167  5.393407  101.744078   234.134475   20.400000
# 5   13.138889  33.168889  5.946667   99.522222   259.116622   20.383333
# 6   20.504079  34.213921  5.313316  102.750263   231.733072   20.675000
# 7   17.247766  33.605595  5.329065   97.455584   232.339203   22.091667
# 8   17.863894  33.669580  5.369073   98.838904   234.127940   22.500000
# 9   16.437935  33.617580  5.492875   98.368418   239.516856   22.500000
# 10  16.649860  33.485743  5.516546   99.035517   240.502595   22.991667
# 11  16.226779  33.640093  5.539148   98.763186   241.461856   23.975000
# 12  19.458958  33.878460  5.531793  105.130020   241.246157   23.933333
# 13  15.373122  33.562444  5.858069  103.366458   255.314703   23.366667
# ...

# %%
df_selected_features_dropna.describe()
# Out:
#           T_degC     Salnty     O2ml_L       O2Sat  Oxy_µmol/Kg         CPI  \
# count  52.000000  52.000000  52.000000   52.000000    52.000000   52.000000
# mean   16.629875  33.508571   5.760495  103.705369   251.326285  103.776893
# std     1.594110   0.352273   0.304503    3.464758    13.047392   74.300030
# min    12.290000  32.878000   4.858478   91.702174   211.802204   19.366667
# 25%    15.952272  33.326525   5.695688  103.364424   248.332853   25.233333
# 50%    16.387645  33.485048   5.831869  104.074804   254.267045  100.895833
# 75%    17.090740  33.557736   5.925027  105.195098   258.266020  174.093750
# max    21.833750  35.304000   6.405000  110.600000   279.102000  240.556333
#
#           CRUSTACEA     MAMMALIA      MOLLUSCA        PISCES  Abalones nei
# count     52.000000    52.000000     52.000000     52.000000     52.000000
# mean    9691.347398  1557.911313  12970.022399   7083.877074    778.403846
# ...

# %%
import seaborn as sns

# Compute the correlation matrix
corr_matrix =df_selected_features_dropna .corr()

# Print the correlation matrix
print(corr_matrix)
# Out:
#                 T_degC    Salnty    O2ml_L     O2Sat  Oxy_µmol/Kg       CPI  \
# T_degC        1.000000  0.703461 -0.825621 -0.174186    -0.821420 -0.258531
# Salnty        0.703461  1.000000 -0.621744 -0.070702    -0.648711 -0.334698
# O2ml_L       -0.825621 -0.621744  1.000000  0.654062     0.987161  0.491760
# O2Sat        -0.174186 -0.070702  0.654062  1.000000     0.661022  0.449480
# Oxy_µmol/Kg  -0.821420 -0.648711  0.987161  0.661022     1.000000  0.479630
# CPI          -0.258531 -0.334698  0.491760  0.449480     0.479630  1.000000
# CRUSTACEA     0.147267  0.137973 -0.228857 -0.193679    -0.222404 -0.708800
# MAMMALIA      0.178509  0.183002 -0.415588 -0.451993    -0.399339 -0.773031
# MOLLUSCA      0.121882 -0.100067 -0.292126 -0.331210    -0.259496 -0.443860
# PISCES       -0.044100 -0.313382 -0.012822 -0.116574    -0.003040  0.239680
# Abalones nei  0.288315  0.262448 -0.490790 -0.445823    -0.470247 -0.860879
#
# ...

# %%
# Plot the heatmap
fig, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
import seaborn as sns

# create scatter plots for all columns
sns.pairplot(df_selected_features_dropna )
# Set the labels and increase the font size
plt.xlabel('Temperature (°C)', fontsize=14)
plt.ylabel('Salinity', fontsize=14)
plt.show()
