# %%
import pandas as pd
import numpy as np

# %%
merged_CPI_PPI_df = pd.read_csv('merged_CPI_PPI.csv')

# %%
#read calco csv file
depth1_calco_df = pd.read_csv('grouped_1_Depthm_data.csv')
# merge the dataframes on the "year_month" column
merged_depth1_calco_CPI_PPI_df = pd.merge(depth1_calco_df, merged_CPI_PPI_df, on="year_month",how='outer')

# %%
merged_depth1_calco_CPI_PPI_df
# Out:
#         year  month  Cst_Cnt   Btl_Cnt  Depthm  T_degC  Salnty  O2ml_L  \
# 0     1950.0   10.0   1937.0   59484.0     1.0   19.54   33.17   4.955
# 1     1951.0    1.0   2340.0   70007.0     1.0   14.22     NaN   5.300
# 2     1951.0    6.0   2960.0   88977.0     1.0     NaN     NaN   5.860
# 3     1952.0   10.0   4971.0  134630.0     1.0   19.33   33.49     NaN
# 4     1954.0    2.0   6645.5  171796.0     1.0   15.10   33.50     NaN
# ...      ...    ...      ...       ...     ...     ...     ...     ...
# 1053     NaN    NaN      NaN       NaN     NaN     NaN     NaN     NaN
# 1054     NaN    NaN      NaN       NaN     NaN     NaN     NaN     NaN
# 1055     NaN    NaN      NaN       NaN     NaN     NaN     NaN     NaN
# 1056     NaN    NaN      NaN       NaN     NaN     NaN     NaN     NaN
# 1057     NaN    NaN      NaN       NaN     NaN     NaN     NaN     NaN
#
#        STheta  O2Sat  ...  DIC2  TA1  TA2  pH2  pH1  year_month   Series ID_x  \
# ...

# %%
merged_depth1_calco_CPI_PPI_df.to_csv('merged_1_depth_CPI_PPI.csv',index = False)
